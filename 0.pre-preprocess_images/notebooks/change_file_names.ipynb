# %% [markdown]
# Replace the strings to rename the file names

# %%
import pathlib

# %%
# set path to the input files
input_path = pathlib.Path("../../data/00.raw_images_ims/").resolve()

# set path to the output files
output_path = pathlib.Path("../../data/0.raw_images_tiff/").resolve()

# create output path if it does not exist
output_path.mkdir(parents=True, exist_ok=True)

# get all files in the input path
files = input_path.glob("*.ims")

# %%
# get all files in the input path
files = input_path.glob("*.ims")
for file in files:
    # extract the file path
    path = file.parent
    new_file = (
        str(file)
        .replace(" ", "_")
        .replace("561_RFP_CF40_iXon_EMCCD_", "")
        .replace("Protocol_7_", "")
        .replace("CZC14992TJ", "")
        .split("_2024-")[0]
        .split("fixed_")[1]
    )
    new_file = f"{path}/{new_file}.ims"
    print(new_file)
    # rename the file
    file.rename(new_file)
# Out:
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_1_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_3_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_9_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_4_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_3_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_13_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_9_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_4_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_6_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_6_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_5_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_14_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_11_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_2_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_12_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_11_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_12_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_2_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_5_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_5_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_5_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_7_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_15_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_7_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_14_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_1_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_8_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_8_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_9_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_3_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_7_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_1_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_13_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_7_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_8_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_4_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_14_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_13_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_10_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_6_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_8_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_11_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_6_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_2_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_4_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_1_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_10_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_4_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_9_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_3_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_7_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_10_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_12_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_14_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_13_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_10_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_5_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_2_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_10_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_13_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_13_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_9_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_1_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_14_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_8_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_5_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_2_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_9_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_12_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_6_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_1_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_3_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_1_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_12_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_6_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_3_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_11_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_14_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_2_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_7_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_10_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_8_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_1_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/high_11_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_6_L.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/unsel_12_R.ims
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/00.raw_images_ims/wt_4_L.ims
